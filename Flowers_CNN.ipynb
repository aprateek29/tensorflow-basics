# %% [markdown]
# Flowers Image Classification

# %%
import os
import numpy as np
import glob
import shutil
import matplotlib.pyplot as plt

# %%
import tensorflow as tf

from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, Flatten, Dropout, MaxPooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
_URL = "https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz"

zip_file = tf.keras.utils.get_file(origin=_URL,
                                   fname="flower_photos.tgz",
                                   extract=True)

base_dir = os.path.join(os.path.dirname(zip_file), 'flower_photos')
# Out:
# Downloading data from https://storage.googleapis.com/download.tensorflow.org/example_images/flower_photos.tgz
# 228818944/228813984 [==============================] - 10s 0us/step

# %%
classes = ['roses', 'daisy', 'dandelion', 'sunflowers', 'tulips']

# %%
for cl in classes:
  img_path = os.path.join(base_dir, cl)
  images = glob.glob(img_path + '/*.jpg')
  print('{}: {} Images'.format(cl, len(images)))
  num_train = int(round(len(images)*0.8))
  train, val = images[:num_train], images[num_train:]

  for t in train:
    if not os.path.exists(os.path.join(base_dir, 'train', cl)):
      os.makedirs(os.path.join(base_dir, 'train', cl))
    shutil.move(t, os.path.join(base_dir, 'train', cl))

  for v in val:
    if not os.path.exists(os.path.join(base_dir, 'val', cl)):
      os.makedirs(os.path.join(base_dir, 'val', cl))
    shutil.move(v, os.path.join(base_dir, 'val', cl))
# Out:
# roses: 641 Images
# daisy: 633 Images
# dandelion: 898 Images
# sunflowers: 699 Images
# tulips: 799 Images

# %%
round(len(images) * 0.8)
# Out:
# 639

# %%
train_dir = os.path.join(base_dir, 'train')
val_dir = os.path.join(base_dir, 'val')

# %%
batch_size = 100
IMG_SHAPE = 150

# %%
image_gen_train = ImageDataGenerator(
                    rescale=1./255,
                    rotation_range=45,
                    width_shift_range=.15,
                    height_shift_range=.15,
                    horizontal_flip=True,
                    zoom_range=0.5
                    )


train_data_gen = image_gen_train.flow_from_directory(
                                                batch_size=batch_size,
                                                directory=train_dir,
                                                shuffle=True,
                                                target_size=(IMG_SHAPE,IMG_SHAPE),
                                                class_mode='sparse'
                                                )
# Out:
# Found 2935 images belonging to 5 classes.

# %%
# This function will plot images in the form of a grid with 1 row and 5 columns where images are placed in each column.
def plotImages(images_arr):
    fig, axes = plt.subplots(1, 5, figsize=(20,20))
    axes = axes.flatten()
    for img, ax in zip( images_arr, axes):
        ax.imshow(img)
    plt.tight_layout()
    plt.show()

# %%
augmented_images = [train_data_gen[0][0][0] for i in range(5)]
plotImages(augmented_images)

# %%
image_gen_val = ImageDataGenerator(rescale=1./255)

val_data_gen = image_gen_val.flow_from_directory(batch_size=batch_size,
                                                 directory=val_dir,
                                                 target_size=(IMG_SHAPE, IMG_SHAPE),
                                                 class_mode='sparse')
# Out:
# Found 735 images belonging to 5 classes.

# %%
model = Sequential()

model.add(Conv2D(16, 3, padding='same', activation='relu', input_shape=(IMG_SHAPE,IMG_SHAPE, 3)))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(32, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, 3, padding='same', activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dropout(0.2))
model.add(Dense(512, activation='relu'))

model.add(Dropout(0.2))
model.add(Dense(5))

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
epochs = 80

history = model.fit_generator(
    train_data_gen,
    steps_per_epoch=int(np.ceil(train_data_gen.n / float(batch_size))),
    epochs=epochs,
    validation_data=val_data_gen,
    validation_steps=int(np.ceil(val_data_gen.n / float(batch_size)))
)
# Out:
# WARNING:tensorflow:From <ipython-input-15-7fa7f550ff06>:8: Model.fit_generator (from tensorflow.python.keras.engine.training) is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use Model.fit, which supports generators.
# Epoch 1/80
# 30/30 [==============================] - 21s 702ms/step - loss: 1.5298 - accuracy: 0.3451 - val_loss: 1.3125 - val_accuracy: 0.4476
# Epoch 2/80
# 30/30 [==============================] - 21s 711ms/step - loss: 1.2286 - accuracy: 0.4831 - val_loss: 1.1101 - val_accuracy: 0.5578
# Epoch 3/80
# 30/30 [==============================] - 22s 724ms/step - loss: 1.1332 - accuracy: 0.5322 - val_loss: 1.0645 - val_accuracy: 0.5796
# Epoch 4/80
# 30/30 [==============================] - 22s 726ms/step - loss: 1.0961 - accuracy: 0.5584 - val_loss: 1.0840 - val_accuracy: 0.5878
# Epoch 5/80
# 30/30 [==============================] - 22s 734ms/step - loss: 1.0127 - accuracy: 0.6181 - val_loss: 0.9418 - val_accuracy: 0.6476
# Epoch 6/80
# 30/30 [==============================] - 22s 731ms/step - loss: 0.9662 - accuracy: 0.6147 - val_loss: 0.9492 - val_accuracy: 0.6544
# Epoch 7/80
# 30/30 [==============================] - 22s 741ms/step - loss: 0.9293 - accuracy: 0.6388 - val_loss: 0.8963 - val_accuracy: 0.6571
# Epoch 8/80
# 30/30 [==============================] - 22s 736ms/step - loss: 0.8925 - accuracy: 0.6579 - val_loss: 0.8971 - val_accuracy: 0.6857
# Epoch 9/80
# 30/30 [==============================] - 22s 733ms/step - loss: 0.8835 - accuracy: 0.6484 - val_loss: 0.8643 - val_accuracy: 0.6844
# Epoch 10/80
# 30/30 [==============================] - 22s 744ms/step - loss: 0.8428 - accuracy: 0.6801 - val_loss: 0.8527 - val_accuracy: 0.6925
# Epoch 11/80
# 30/30 [==============================] - 22s 748ms/step - loss: 0.8244 - accuracy: 0.6746 - val_loss: 0.7440 - val_accuracy: 0.7238
# Epoch 12/80
# 30/30 [==============================] - 22s 737ms/step - loss: 0.8127 - accuracy: 0.6794 - val_loss: 0.7516 - val_accuracy: 0.7197
# Epoch 13/80
# 30/30 [==============================] - 22s 743ms/step - loss: 0.7912 - accuracy: 0.6876 - val_loss: 0.7969 - val_accuracy: 0.6816
# Epoch 14/80
# 30/30 [==============================] - 22s 736ms/step - loss: 0.7881 - accuracy: 0.6913 - val_loss: 0.7565 - val_accuracy: 0.7170
# Epoch 15/80
# 30/30 [==============================] - 21s 714ms/step - loss: 0.7490 - accuracy: 0.7114 - val_loss: 0.7122 - val_accuracy: 0.7333
# Epoch 16/80
# 30/30 [==============================] - 21s 703ms/step - loss: 0.7456 - accuracy: 0.7114 - val_loss: 0.6797 - val_accuracy: 0.7469
# Epoch 17/80
# 30/30 [==============================] - 21s 709ms/step - loss: 0.7313 - accuracy: 0.7155 - val_loss: 0.7480 - val_accuracy: 0.7129
# Epoch 18/80
# 30/30 [==============================] - 21s 695ms/step - loss: 0.7216 - accuracy: 0.7264 - val_loss: 0.6754 - val_accuracy: 0.7483
# Epoch 19/80
# 30/30 [==============================] - 21s 688ms/step - loss: 0.7084 - accuracy: 0.7264 - val_loss: 0.7735 - val_accuracy: 0.7061
# Epoch 20/80
# 30/30 [==============================] - 21s 689ms/step - loss: 0.6998 - accuracy: 0.7295 - val_loss: 0.6652 - val_accuracy: 0.7483
# Epoch 21/80
# 30/30 [==============================] - 21s 695ms/step - loss: 0.6664 - accuracy: 0.7421 - val_loss: 0.6708 - val_accuracy: 0.7306
# Epoch 22/80
# 30/30 [==============================] - 21s 686ms/step - loss: 0.6824 - accuracy: 0.7319 - val_loss: 0.6843 - val_accuracy: 0.7442
# Epoch 23/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.6599 - accuracy: 0.7455 - val_loss: 0.6428 - val_accuracy: 0.7415
# Epoch 24/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.6813 - accuracy: 0.7329 - val_loss: 0.6736 - val_accuracy: 0.7429
# Epoch 25/80
# 30/30 [==============================] - 21s 688ms/step - loss: 0.6792 - accuracy: 0.7428 - val_loss: 0.7250 - val_accuracy: 0.7197
# Epoch 26/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.6413 - accuracy: 0.7496 - val_loss: 0.6321 - val_accuracy: 0.7510
# Epoch 27/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.6297 - accuracy: 0.7468 - val_loss: 0.6517 - val_accuracy: 0.7415
# Epoch 28/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.6297 - accuracy: 0.7506 - val_loss: 0.6229 - val_accuracy: 0.7605
# Epoch 29/80
# 30/30 [==============================] - 21s 685ms/step - loss: 0.6172 - accuracy: 0.7591 - val_loss: 0.6265 - val_accuracy: 0.7592
# Epoch 30/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.6276 - accuracy: 0.7618 - val_loss: 0.6940 - val_accuracy: 0.7415
# Epoch 31/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.6038 - accuracy: 0.7748 - val_loss: 0.6438 - val_accuracy: 0.7565
# Epoch 32/80
# 30/30 [==============================] - 21s 692ms/step - loss: 0.6092 - accuracy: 0.7615 - val_loss: 0.6312 - val_accuracy: 0.7524
# Epoch 33/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.5954 - accuracy: 0.7700 - val_loss: 0.6764 - val_accuracy: 0.7293
# Epoch 34/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.5973 - accuracy: 0.7761 - val_loss: 0.6109 - val_accuracy: 0.7864
# Epoch 35/80
# 30/30 [==============================] - 21s 687ms/step - loss: 0.5781 - accuracy: 0.7785 - val_loss: 0.6294 - val_accuracy: 0.7537
# Epoch 36/80
# 30/30 [==============================] - 21s 687ms/step - loss: 0.5767 - accuracy: 0.7707 - val_loss: 0.6456 - val_accuracy: 0.7469
# Epoch 37/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.5555 - accuracy: 0.7792 - val_loss: 0.6021 - val_accuracy: 0.7741
# Epoch 38/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.5629 - accuracy: 0.7799 - val_loss: 0.6648 - val_accuracy: 0.7565
# Epoch 39/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.5315 - accuracy: 0.7969 - val_loss: 0.6864 - val_accuracy: 0.7551
# Epoch 40/80
# 30/30 [==============================] - 21s 687ms/step - loss: 0.5358 - accuracy: 0.7877 - val_loss: 0.6490 - val_accuracy: 0.7646
# Epoch 41/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.5390 - accuracy: 0.7939 - val_loss: 0.6443 - val_accuracy: 0.7660
# Epoch 42/80
# 30/30 [==============================] - 20s 678ms/step - loss: 0.5327 - accuracy: 0.7969 - val_loss: 0.6209 - val_accuracy: 0.7864
# Epoch 43/80
# 30/30 [==============================] - 20s 677ms/step - loss: 0.5232 - accuracy: 0.8020 - val_loss: 0.6710 - val_accuracy: 0.7469
# Epoch 44/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.5406 - accuracy: 0.7826 - val_loss: 0.6527 - val_accuracy: 0.7592
# Epoch 45/80
# 30/30 [==============================] - 20s 678ms/step - loss: 0.5192 - accuracy: 0.7966 - val_loss: 0.6168 - val_accuracy: 0.7769
# Epoch 46/80
# 30/30 [==============================] - 20s 679ms/step - loss: 0.5060 - accuracy: 0.8034 - val_loss: 0.7042 - val_accuracy: 0.7483
# Epoch 47/80
# 30/30 [==============================] - 21s 689ms/step - loss: 0.5038 - accuracy: 0.8109 - val_loss: 0.6218 - val_accuracy: 0.7687
# Epoch 48/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.4928 - accuracy: 0.8010 - val_loss: 0.6366 - val_accuracy: 0.7660
# Epoch 49/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.4809 - accuracy: 0.8160 - val_loss: 0.6539 - val_accuracy: 0.7701
# Epoch 50/80
# 30/30 [==============================] - 20s 680ms/step - loss: 0.5069 - accuracy: 0.8051 - val_loss: 0.6616 - val_accuracy: 0.7769
# Epoch 51/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.4908 - accuracy: 0.8201 - val_loss: 0.6367 - val_accuracy: 0.7714
# Epoch 52/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.4685 - accuracy: 0.8232 - val_loss: 0.6431 - val_accuracy: 0.7660
# Epoch 53/80
# 30/30 [==============================] - 20s 680ms/step - loss: 0.4697 - accuracy: 0.8177 - val_loss: 0.6605 - val_accuracy: 0.7592
# Epoch 54/80
# 30/30 [==============================] - 20s 680ms/step - loss: 0.4660 - accuracy: 0.8201 - val_loss: 0.6434 - val_accuracy: 0.7837
# Epoch 55/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.4740 - accuracy: 0.8218 - val_loss: 0.6054 - val_accuracy: 0.7905
# Epoch 56/80
# 30/30 [==============================] - 20s 680ms/step - loss: 0.4717 - accuracy: 0.8296 - val_loss: 0.6402 - val_accuracy: 0.7673
# Epoch 57/80
# 30/30 [==============================] - 21s 686ms/step - loss: 0.4487 - accuracy: 0.8208 - val_loss: 0.6143 - val_accuracy: 0.7728
# Epoch 58/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.4333 - accuracy: 0.8375 - val_loss: 0.6050 - val_accuracy: 0.8000
# Epoch 59/80
# 30/30 [==============================] - 21s 692ms/step - loss: 0.4554 - accuracy: 0.8252 - val_loss: 0.6049 - val_accuracy: 0.7823
# Epoch 60/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.4482 - accuracy: 0.8276 - val_loss: 0.6244 - val_accuracy: 0.7714
# Epoch 61/80
# 30/30 [==============================] - 21s 688ms/step - loss: 0.4438 - accuracy: 0.8334 - val_loss: 0.6250 - val_accuracy: 0.7769
# Epoch 62/80
# 30/30 [==============================] - 21s 685ms/step - loss: 0.4378 - accuracy: 0.8348 - val_loss: 0.6586 - val_accuracy: 0.7646
# Epoch 63/80
# 30/30 [==============================] - 21s 686ms/step - loss: 0.4520 - accuracy: 0.8266 - val_loss: 0.6157 - val_accuracy: 0.7932
# Epoch 64/80
# 30/30 [==============================] - 21s 685ms/step - loss: 0.4025 - accuracy: 0.8504 - val_loss: 0.6222 - val_accuracy: 0.7823
# Epoch 65/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.4182 - accuracy: 0.8399 - val_loss: 0.7392 - val_accuracy: 0.7524
# Epoch 66/80
# 30/30 [==============================] - 20s 682ms/step - loss: 0.4301 - accuracy: 0.8324 - val_loss: 0.6168 - val_accuracy: 0.7878
# Epoch 67/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.4002 - accuracy: 0.8450 - val_loss: 0.6303 - val_accuracy: 0.7837
# Epoch 68/80
# 30/30 [==============================] - 21s 685ms/step - loss: 0.4474 - accuracy: 0.8279 - val_loss: 0.6866 - val_accuracy: 0.7728
# Epoch 69/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.4064 - accuracy: 0.8457 - val_loss: 0.7700 - val_accuracy: 0.7524
# Epoch 70/80
# 30/30 [==============================] - 20s 683ms/step - loss: 0.4339 - accuracy: 0.8286 - val_loss: 0.6663 - val_accuracy: 0.7864
# Epoch 71/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.4230 - accuracy: 0.8487 - val_loss: 0.6704 - val_accuracy: 0.7891
# Epoch 72/80
# 30/30 [==============================] - 20s 680ms/step - loss: 0.4052 - accuracy: 0.8436 - val_loss: 0.6631 - val_accuracy: 0.7850
# Epoch 73/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.3971 - accuracy: 0.8576 - val_loss: 0.6357 - val_accuracy: 0.7728
# Epoch 74/80
# 30/30 [==============================] - 21s 684ms/step - loss: 0.3944 - accuracy: 0.8511 - val_loss: 0.6652 - val_accuracy: 0.7796
# Epoch 75/80
# 30/30 [==============================] - 21s 695ms/step - loss: 0.3894 - accuracy: 0.8555 - val_loss: 0.6821 - val_accuracy: 0.7782
# Epoch 76/80
# 30/30 [==============================] - 21s 690ms/step - loss: 0.3717 - accuracy: 0.8535 - val_loss: 0.6734 - val_accuracy: 0.7918
# Epoch 77/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.3761 - accuracy: 0.8494 - val_loss: 0.7046 - val_accuracy: 0.7782
# Epoch 78/80
# 30/30 [==============================] - 21s 688ms/step - loss: 0.3705 - accuracy: 0.8555 - val_loss: 0.6353 - val_accuracy: 0.7864
# Epoch 79/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.3686 - accuracy: 0.8661 - val_loss: 0.7147 - val_accuracy: 0.7782
# Epoch 80/80
# 30/30 [==============================] - 20s 681ms/step - loss: 0.3966 - accuracy: 0.8474 - val_loss: 0.6806 - val_accuracy: 0.7864

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()
